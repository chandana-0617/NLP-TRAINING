# %% [markdown]
# <a href="https://colab.research.google.com/github/chandana-0617/NLP-TRAINING/blob/main/day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a List, tuple and Dictionary with 5 elements in it and how to access few elements based on the index. Try  with different examples

a=[1,2,3,4,"chandu"]
b=(11,12,13,14,"chandana")
c={"name":"vinuu","age":15,"class":10,"Grade":"B","Section":"Tulip"}
print(a)
print(b)
print(c)
print(a[4])
print(b[3])
print(c["Section"])
# Out:
# [1, 2, 3, 4, 'chandu']
# (11, 12, 13, 14, 'chandana')
# {'name': 'vinuu', 'age': 15, 'class': 10, 'Grade': 'B', 'Section': 'Tulip'}
# chandu
# 14
# Tulip
