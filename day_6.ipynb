# %% [markdown]
# <a href="https://colab.research.google.com/github/chandana-0617/NLP-TRAINING/blob/main/day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
pip install spacy

# %%
""" Write a Python program to using NLTK and Spacy
Convert text to lowercase.
Remove stopwords using NLTK """

import nltk
from nltk.corpus import stopwords
import spacy

nltk.download('stopwords')

nltk_stopwords = set(stopwords.words('english'))
nlp = spacy.load("en_core_web_sm")

def process_text(text):

    text = text.lower()
    doc = nlp(text)

    filtered_words = [token.text for token in doc if token.text not in nltk_stopwords and token.is_alpha]

    return filtered_words

text = input("Enter a text: ")

filtered_text = process_text(text)

print("\nProcessed text (stopwords removed):")
print(" ".join(filtered_text))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Enter a text: Hello World !, I am Chandana, How are you ? .
#
# Processed text (stopwords removed):
# hello world chandana
