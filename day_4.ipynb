# %% [markdown]
# <a href="https://colab.research.google.com/github/chandana-0617/NLP-TRAINING/blob/main/day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Write a Python program to calculate the sum of all even numbers between 1 and a given positive integer n"""

def sum_of_even_numbers(n):
    if n < 1:
        return "Enter a positive integer."
    return sum(range(2, n + 1, 2))

n = int(input("Enter a positive integer: "))
print(f"The sum of all even numbers between 1 and {n} is {sum_of_even_numbers(n)}.")
# Out:
# Enter a positive integer: 100
# The sum of all even numbers between 1 and 100 is 2550.
