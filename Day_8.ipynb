# %% [markdown]
# <a href="https://colab.research.google.com/github/chandana-0617/NLP-TRAINING/blob/main/Day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
""" Write a Python script that:
       Tokenizes a sample paragraph into words and sentences. """

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

nltk.download('punkt_tab')

paragraph = """
Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence.
It involves understanding and generating human language. Tokenization is an essential step in NLP.
"""

def tokenize_paragraph(paragraph):
    sentences = sent_tokenize(paragraph)
    words = word_tokenize(paragraph)

    return sentences, words

sentences, words = tokenize_paragraph(paragraph)

print("Original Paragraph:")
print(paragraph)

print("\nTokenized Sentences:")
print(sentences)

print("\nTokenized Words:")
print(words)
# Out:
# Original Paragraph:
#
# Natural Language Processing (NLP) is a fascinating field of Artificial Intelligence.
# It involves understanding and generating human language. Tokenization is an essential step in NLP.
#
#
# Tokenized Sentences:
# ['\nNatural Language Processing (NLP) is a fascinating field of Artificial Intelligence.', 'It involves understanding and generating human language.', 'Tokenization is an essential step in NLP.']
#
# Tokenized Words:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'fascinating', 'field', 'of', 'Artificial', 'Intelligence', '.', 'It', 'involves', 'understanding', 'and', 'generating', 'human', 'language', '.', 'Tokenization', 'is', 'an', 'essential', 'step', 'in', 'NLP', '.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
